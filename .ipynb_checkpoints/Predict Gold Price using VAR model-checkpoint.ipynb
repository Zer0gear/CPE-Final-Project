# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import preprocessing
from scipy import stats
import matplotlib.dates as mdates

# Import Statsmodels
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

# %% [markdown]
# # DATA PREPARATION

# %% [markdown]
# ## import dataset

# %%
gold =pd.read_csv("./gld_price_data.csv")
gas =pd.read_csv("./natural_gas_data.csv")
oil = pd.read_csv('./crude_oil_eu_data.csv')
dolla = pd.read_csv('./dolla_index_data.csv')
etf = pd.read_csv('./etf_data.csv')
nem = pd.read_csv('./NEM_data.csv')
dem = pd.read_csv('./gold_demand_data.csv')
sil = pd.DataFrame(pd.read_csv('./silver_price_data.csv'), columns={'Date','USD'})

# %%
sil
# Out:
#              Date     USD
# 0      2020-12-17  25.740
# 1      2020-12-16  25.130
# 2      2020-12-15  24.215
# 3      2020-12-14  23.855
# 4      2020-12-11  23.815
# 5      2020-12-10  23.885
# 6      2020-12-09  24.085
# 7      2020-12-08  24.475
# 8      2020-12-07  23.750
# 9      2020-12-04  24.225
# 10     2020-12-03  24.170
# 11     2020-12-02  23.980
# 12     2020-12-01  23.535
# 13     2020-11-30  22.150
# 14     2020-11-27  23.135
# 15     2020-11-26  23.360
# 16     2020-11-25  23.410
# 17     2020-11-24  23.155
# 18     2020-11-23  23.905
# 19     2020-11-20  24.165
# 20     2020-11-19  23.980
# 21     2020-11-18  24.315
# 22     2020-11-17  24.630
# 23     2020-11-16  24.265
# 24     2020-11-13  24.245
# 25     2020-11-12  24.215
# 26     2020-11-11  24.210
# 27     2020-11-10  24.195
# 28     2020-11-09  25.105
# 29     2020-11-06  25.780
# ...           ...     ...
# 13369  1968-02-12   1.929
# 13370  1968-02-09   1.938
# 13371  1968-02-08   1.979
# ...

# %% [markdown]
# ## data preprocessing

# %%
### daily data only
### df : list of dataframe , name : list of dataframe's value's name , color : list of data's color
df = [gold,gas,oil,dolla,etf,nem,sil]
name = ['gld_price', 'gas_price', 'oil_price','dolla_index','etf_index','newmond_share','silver_price']
color = ['red', 'green', 'blue', 'violet','purple','orange','silver']

# %%
### rename all data columns
for i in range(len(df)):
    df[i] = df[i].rename(columns={df[i].columns[0]:'date',df[i].columns[1]:name[i]})

# %%
### set date as index and join all data
data = df[0].set_index('date')
for i in range(len(df)):
    if i > 0:
        data = data.join(df[i].set_index('date'))

# %%
data = data.replace('.', np.NaN)

# %%
data = data.dropna()

# %%
### convert index to datetime64
data = pd.DataFrame(data, index = np.array([np.datetime64(i) for i in data.index]))

# %%
### convert all data values to float
for i in data.columns:
    data[i] = data[i].astype(str).astype(float)

# %%
### join quarter data 
# tmp = pandas.DataFrame(pandas.Series(data.index, index = data.index).dt.quarter)[0]
# l = []
# for i in range(len(tmp)):
#     l.append(str(tmp.index[i]).split('-')[0] +"'" + 'Q' + (str(tmp[i])))
# tmp = pandas.DataFrame(l,index = data.index)
# data = data.join(tmp)

# %%
# data = data.rename(columns={data.columns[6]:'quarter'})

# %%
# data = data.set_index(data['quarter']).drop(columns={'quarter'})

# %%
# data = data.groupby(data.index).mean().join(dem.set_index(dem['date'])).drop(columns={'date'})

# %%
# data = data.dropna()

# %%
# data['Gold demand'] = data['Gold demand'].astype(str).astype(float)

# %%
data.head(10)
# Out:
#             gld_price  gas_price  oil_price  dolla_index  etf_index  \
# 2015-10-21    1174.40       2.37      46.72     109.7689      15.90
# 2015-10-22    1166.45       2.37      46.59     110.0266      15.59
# 2015-10-23    1171.55       2.28      46.30     110.4233      15.59
# 2015-10-26    1168.50       2.18      46.57     110.1994      15.78
# 2015-10-27    1165.75       2.14      45.54     110.4771      15.30
# 2015-10-28    1171.50       2.14      47.60     110.2234      15.63
# 2015-10-29    1159.00       2.15      48.04     110.7986      15.77
# 2015-10-30    1147.75       1.98      48.00     110.1996      15.39
# 2015-11-02    1135.80       1.92      47.91     110.2102      15.28
# 2015-11-03    1130.90       1.92      48.00     110.2343      17.19
#
#             newmond_share  silver_price
# 2015-10-21      18.420000         15.75
# 2015-10-22      19.030001         15.77
# 2015-10-23      19.549999         15.98
# 2015-10-26      18.799999         16.10
# ...

# %% [markdown]
# ## DATA EXPLORATION

# %%
#normalization and plot function
def plot_df(data,columns):
    plt_data = data.copy()
    min_max_scaler = preprocessing.MinMaxScaler()
    for i in data.columns:
        scale = min_max_scaler.fit_transform(plt_data[i].values.reshape(-1,1))
        temp = pd.DataFrame(scale, columns=[i], index = data.index)
        plt_data[i] = temp
    ax = plt.gca()
    plt_data.plot(kind='line', y='gld_price',ax=ax,color='blue',figsize=(10,5))
    plt_data.plot(kind='line', y=columns,ax=ax,color='red')
    plt.show()

# %%
#plot all feature
for i in data.columns:
    if i != 'gld_price':
        plot_df(data,i)

# %%
# plt_list = [(data.columns[i],color[i]) for i in range(len(data.columns))]

# %%
# ### plot gold and feature
# years = mdates.YearLocator()   # every year
# months = mdates.MonthLocator()  # every month
# years_fmt = mdates.DateFormatter('%Y')
# fig, ax = plt.subplots(len(data.columns)-1,figsize=(40/len(data.columns)-1,6))
# for i,j in enumerate(ax):
#     j.title.set_text(data.columns[i+1])
#     j.plot(data[data.columns[0]],color=color[0])
#     j.plot(data[data.columns[i+1]],color=color[i+1])
#     j.xaxis.set_major_locator(years)
#     j.xaxis.set_major_formatter(years_fmt)
#     j.xaxis.set_minor_locator(months)
#     datemin = np.datetime64(data.index[0], 'Y')
#     datemax = np.datetime64(data.index[-1], 'Y') + np.timedelta64(1, 'Y')
#     j.set_xlim(datemin, datemax)
#     j.format_xdata = mdates.DateFormatter('%Y-%m-%d')
#     j.grid(True)

# plt.tight_layout()

# %%
# plt.plot(data['gld_price'],color='red')
# plt.plot(data['newmond_share'],color='orange')

# %%
## Data Exploration

# %%
# l = []
# ex = df.copy()

# %%
# ### rename all data columns
# for i in range(len(ex)):
#     ex[i] = ex[i].rename(columns={ex[i].columns[0]:'date',ex[i].columns[1]:name[i]})

# %%
# ### set date as index and join all data
# ex_data = ex[0].set_index('date')
# for i in range(len(ex)):
#     if i > 0:
#         ex_data = ex_data.join(ex[i].set_index('date'))

# %%
# ex_data = ex_data.replace('.', np.NaN)
# ex_data = ex_data.dropna()

# %%
# for i in ex_data.columns:
#     ex_data[i] = ex_data[i].astype(str).astype(float)

# %%
# #### Mean / Stdev 
# for i in range(len(ex_data.columns)):
#     mean = sum(ex_data[ex_data.columns[i]].values)/len(ex_data[ex_data.columns[i]].values)
#     stdev = statistics.stdev(ex_data[ex_data.columns[i]].values)
#     print(name[i])
#     print(f'Mean: {mean}')
#     print(f'Stdev: {stdev}')
#     print()

# %%
# #### Normal Distribution Testing 
# alpha = 1e-3
# for i in range(len(ex_data.columns)):
#     print(name[i])
#     k2, p = stats.normaltest(ex_data[ex_data.columns[i]].values)
#     print(f'k2: {k2}')
#     print(f'p: {p:g}')
#     if p < alpha:  # null hypothesis: gld_price comes from a normal distribution
#         print("The null hypothesis can be rejected")
#     else:
#         print("The null hypothesis cannot be rejected")
#     print()

# %% [markdown]
# ## CORRELATION

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_fba1198a_530c_11eb_9c30_309c23905c57row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_fba1198a_530c_11eb_9c30_309c23905c57row0_col1 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_fba1198a_530c_11eb_9c30_309c23905c57row0_col2 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_fba1198a_530c_11eb_9c30_309c23905c57row0_col3 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_fba1198a_530c_11eb_9c30_309c23905c57row0_col4 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_fba1198a_530c_11eb_9c30_309c23905c57row0_col5 {
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }    #T_fba1198a_530c_11eb_9c30_309c23905c57row0_col6 {
#             background-color:  #f7a889;
#             color:  #000000;
# ...

# %%
## drop unusable  feature
data = data.drop(columns=[data.columns[i] for i in [2]])

# %% [markdown]
# ## GRANGER CAUSATION TEST

# %%
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.vector_ar.vecm import coint_johansen
maxlag=12
test = 'ssr_chi2test'
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

def cointegration_test(df, alpha=0.05): 
    """Perform Johanson's Cointegration Test and Report Summary"""
    out = coint_johansen(df,-1,5)
    d = {'0.90':0, '0.95':1, '0.99':2}
    traces = out.lr1
    cvts = out.cvt[:, d[str(1-alpha)]]
    def adjust(val, length= 6): return str(val).ljust(length)

    # Summary
    print('Name   ::  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

# %%
granger = grangers_causation_matrix(data, variables = data.columns)

# %%
granger
# Out:
#                  gld_price_x  gas_price_x  dolla_index_x  etf_index_x  \
# gld_price_y           1.0000       0.3714         0.0000       0.0019
# gas_price_y           0.0063       1.0000         0.2174       0.0026
# dolla_index_y         0.0000       0.0424         1.0000       0.0000
# etf_index_y           0.0015       0.0036         0.0000       1.0000
# newmond_share_y       0.0010       0.1198         0.0034       0.0000
# silver_price_y        0.0099       0.2877         0.0000       0.0007
#
#                  newmond_share_x  silver_price_x
# gld_price_y               0.0000          0.0000
# gas_price_y               0.1178          0.4713
# dolla_index_y             0.0000          0.0003
# etf_index_y               0.0001          0.0005
# newmond_share_y           1.0000          0.0000
# silver_price_y            0.0000          1.0000

# %%
## drop unusable  feature
data = data.drop(columns=[data.columns[i] for i in [1]])

# %%
data
# Out:
#             gld_price  dolla_index  etf_index  newmond_share  silver_price
# 2015-10-21    1174.40     109.7689      15.90      18.420000        15.750
# 2015-10-22    1166.45     110.0266      15.59      19.030001        15.770
# 2015-10-23    1171.55     110.4233      15.59      19.549999        15.980
# 2015-10-26    1168.50     110.1994      15.78      18.799999        16.100
# 2015-10-27    1165.75     110.4771      15.30      18.770000        15.800
# 2015-10-28    1171.50     110.2234      15.63      19.150000        16.030
# 2015-10-29    1159.00     110.7986      15.77      19.889999        15.820
# 2015-10-30    1147.75     110.1996      15.39      19.459999        15.630
# 2015-11-02    1135.80     110.2102      15.28      19.629999        15.400
# 2015-11-03    1130.90     110.2343      17.19      19.219999        15.380
# 2015-11-04    1118.00     110.7034      18.02      19.010000        15.260
# ...

# %% [markdown]
# ## COINTEGRATION TEST

# %%
cointegration_test(data)
# Out:
# Name   ::  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# gld_price ::  65.38     > 60.0627   =>   True
# dolla_index ::  31.02     > 40.1749   =>   False
# etf_index ::  15.91     > 24.2761   =>   False
# newmond_share ::  3.35      > 12.3212   =>   False
# silver_price ::  0.9       > 4.1296    =>   False

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
for name, column in data.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "gld_price"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 0.2211
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.436
#  Critical value 5%     = -2.864
#  Critical value 10%    = -2.568
#  => P-Value = 0.9734. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "dolla_index"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.9919
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.436
#  Critical value 5%     = -2.864
#  Critical value 10%    = -2.568
#  => P-Value = 0.2902. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "etf_index"
# ...

# %%
## 1st Diff
df_diff = data.diff().dropna()

# %%
for name, column in df_diff.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "gld_price"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -11.7487
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.436
#  Critical value 5%     = -2.864
#  Critical value 10%    = -2.568
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "dolla_index"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -32.6449
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.436
#  Critical value 5%     = -2.864
#  Critical value 10%    = -2.568
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "etf_index"
#     -----------------------------------------------
# ...

# %%
#  #2nd diff
#  df_differenced = df_differenced.diff().dropna()
#  for name, column in df_differenced.iteritems():
#      adfuller_test(column, name=column.name)
#      print('\n')

# %%
yearcount = {str(i):0 for i in range(2015,2021)}
for i in data.index:
    if "2015" in str(i):
        yearcount['2015'] += 1
    elif "2016" in str(i):
        yearcount['2016'] += 1
    elif "2017" in str(i):
        yearcount['2017'] += 1
    elif "2018" in str(i):
        yearcount['2018'] += 1
    elif "2019" in str(i):
        yearcount['2019'] += 1
    elif "2020" in str(i):
        yearcount['2020'] += 1

# %%
yearcount
# Out:
# {'2015': 48, '2016': 243, '2017': 243, '2018': 239, '2019': 241, '2020': 182}

# %%
x = df_diff[:-yearcount['2020']]
y = df_diff[-yearcount['2020']:]

# %%
print(len(x))
# Out:
# 1013

# %%
print(len(y))
# Out:
# 182

# %% [markdown]
# # Create VAR model

# %%
def invert_transformation(df_train, df_forecast, second_diff=False):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:        
        # Roll back 2nd Diff
        if second_diff:
            df_fc[str(col)+'_1d'] = (df_train[col].iloc[-1]-df_train[col].iloc[-2]) + df_fc[str(col)+'_2d'].cumsum()
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = df_train[col].iloc[-1] + df_fc[str(col)+'_1d'].cumsum()
    return df_fc

# %%
count = 0
nobs = 7
n = len(x)
pred = pd.DataFrame()
for i in range(n+1,len(df_diff)-7,7):
    df_x = df_diff[i-n-1:i-1]
    df_y = df_diff[i:i+7]['gld_price']
    model = VAR(df_x)
    aic = {'n': 1, 'value':model.fit(1).aic}
    for j in range(2,10):
        result = model.fit(j)
        if result.aic < aic['value']:
            aic['n'] = j
            aic['value'] = result.aic
    
    model_fitted = model.fit(aic['n'])
    lag_order = model_fitted.k_ar
    forecast_input = df_diff.values[-lag_order:]
    fc = model_fitted.forecast(y=forecast_input, steps=nobs)
    df_forecast = pd.DataFrame(fc, index=df_y.index[-nobs:], columns=df_diff.columns + '_1d')
    df_results = invert_transformation(data[i-n-1:i-1], df_forecast, second_diff=False)  
    pred = pred.append(df_results.loc[:, ['gld_price_forecast']])
# Out:
# C:\Users\MSI\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\MSI\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\MSI\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...

# %%
test_data = pd.DataFrame(data[-yearcount['2020']:]['gld_price'])

# %%
pred
# Out:
#             gld_price_forecast
# 2020-01-03         1519.559133
# 2020-01-06         1522.247458
# 2020-01-07         1521.261391
# 2020-01-08         1521.584231
# 2020-01-09         1522.091000
# 2020-01-10         1522.416254
# 2020-01-13         1522.744608
# 2020-01-14         1555.449397
# 2020-01-15         1558.305174
# 2020-01-16         1557.723810
# 2020-01-17         1558.595818
# 2020-01-21         1559.085859
# 2020-01-22         1559.368073
# 2020-01-23         1559.950867
# 2020-01-24         1564.555836
# 2020-01-27         1567.285916
# 2020-01-28         1566.640497
# 2020-01-29         1567.072238
# 2020-01-30         1567.651723
# 2020-01-31         1568.107887
# 2020-02-03         1568.561045
# 2020-02-04         1588.590164
# 2020-02-05         1591.159422
# 2020-02-06         1590.561888
# 2020-02-10         1591.041840
# 2020-02-11         1591.651506
# 2020-02-12         1592.149294
# 2020-02-13         1592.645957
# 2020-02-14         1575.719335
# ...

# %%
test_data
# Out:
#             gld_price
# 2020-01-02    1520.55
# 2020-01-03    1547.40
# 2020-01-06    1576.85
# 2020-01-07    1566.50
# 2020-01-08    1582.85
# 2020-01-09    1547.85
# 2020-01-10    1548.80
# 2020-01-13    1550.35
# 2020-01-14    1544.95
# 2020-01-15    1551.90
# 2020-01-16    1555.20
# 2020-01-17    1556.50
# 2020-01-21    1556.25
# 2020-01-22    1558.10
# 2020-01-23    1554.05
# 2020-01-24    1561.85
# 2020-01-27    1583.45
# 2020-01-28    1579.60
# 2020-01-29    1571.20
# 2020-01-30    1580.40
# 2020-01-31    1580.85
# 2020-02-03    1578.85
# 2020-02-04    1571.20
# 2020-02-05    1552.20
# 2020-02-06    1564.75
# 2020-02-10    1574.05
# 2020-02-11    1567.70
# 2020-02-12    1566.75
# 2020-02-13    1575.00
# 2020-02-14    1576.35
# ...               ...
# 2020-08-14    1948.30
# 2020-08-17    1949.85
# 2020-08-18    2005.15
# 2020-08-19    1993.15
# 2020-08-20    1928.05
# 2020-08-21    1932.85
# 2020-08-24    1947.55
# 2020-08-25    1925.45
# 2020-08-26    1918.50
# ...

# %%
ax = plt.gca()
pred.plot(kind='line', y='gld_price_forecast',ax=ax,color='blue',figsize=(10,5))
test_data.plot(kind='line', y='gld_price',ax=ax,color='red')
plt.show()

# %%
data
# Out:
#             gld_price  dolla_index  etf_index  newmond_share  silver_price
# 2015-10-21    1174.40     109.7689      15.90      18.420000        15.750
# 2015-10-22    1166.45     110.0266      15.59      19.030001        15.770
# 2015-10-23    1171.55     110.4233      15.59      19.549999        15.980
# 2015-10-26    1168.50     110.1994      15.78      18.799999        16.100
# 2015-10-27    1165.75     110.4771      15.30      18.770000        15.800
# 2015-10-28    1171.50     110.2234      15.63      19.150000        16.030
# 2015-10-29    1159.00     110.7986      15.77      19.889999        15.820
# 2015-10-30    1147.75     110.1996      15.39      19.459999        15.630
# 2015-11-02    1135.80     110.2102      15.28      19.629999        15.400
# 2015-11-03    1130.90     110.2343      17.19      19.219999        15.380
# 2015-11-04    1118.00     110.7034      18.02      19.010000        15.260
# ...

# %% [markdown]
# ## Evaluate Model

# %%
from statsmodels.tsa.stattools import acf
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'corr':corr, 'minmax':minmax})

print('Forecast Accuracy of: gld_price')
accuracy_prod = forecast_accuracy(pred['gld_price_forecast'].values, test_data[0:175]['gld_price'])
for k, v in accuracy_prod.items():
    print(k, ': ', round(v,4))
# Out:
# Forecast Accuracy of: gld_price
# mape :  0.024
# me :  19.9266
# mae :  40.799
# mpe :  0.0116
# rmse :  55.2281
# corr :  0.943
# minmax :  0.0231
